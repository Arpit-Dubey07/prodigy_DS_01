# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# Load train and test datasets
train_data = pd.read_csv('C:\\Users\\91771\\OneDrive\\Desktop\\everything\\prodigy_infotech\\house-prices-advanced-regression-techniques\\train.csv')
test_data = pd.read_csv('C:\\Users\\91771\\OneDrive\\Desktop\\everything\\prodigy_infotech\\house-prices-advanced-regression-techniques\\test.csv')

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Select relevant features
train_data = train_data[['Id','GrLivArea', 'BedroomAbvGr', 'FullBath', 'SalePrice']]
test_data = test_data[['Id','GrLivArea', 'BedroomAbvGr', 'FullBath']]

# %%
# Separate features and target variable
X_train = train_data[['Id','GrLivArea', 'BedroomAbvGr', 'FullBath']]
y_train = train_data['SalePrice']

# %%
# Initialize the linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prepare test data
X_test = test_data[['Id','GrLivArea', 'BedroomAbvGr', 'FullBath']]

# Make predictions
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([117534.61181468, 137393.31431737, 200085.71594308, ...,
#         93038.70269998,  92866.99572698, 235875.31379068])

# %%
# Create a DataFrame with predictions
submission = pd.DataFrame({'Id':id,'SalePrice': predictions})

# Save predictions to a CSV file
submission.to_csv('predictions.csv', index=False)

# %%
# Make predictions on the test set (X_test)
predictions = model.predict(X_test)
predictions
# Out:
# array([117534.61181468, 137393.31431737, 200085.71594308, ...,
#         93038.70269998,  92866.99572698, 235875.31379068])
